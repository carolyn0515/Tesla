# %%
import pandas as pd
df = pd.read_csv("tesla_deliveries_dataset_2015_2025.csv")
df
# Out:
#       Year  Month         Region       Model  Estimated_Deliveries  \
# 0     2023      5         Europe     Model S                 17646
# 1     2015      2           Asia     Model X                  3797
# 2     2019      1  North America     Model X                  8411
# 3     2021      2  North America     Model 3                  6555
# 4     2016     12    Middle East     Model Y                 12374
# ...    ...    ...            ...         ...                   ...
# 2635  2021     10    Middle East     Model Y                 13488
# 2636  2019      7    Middle East     Model S                 18300
# 2637  2019      9           Asia     Model S                 13291
# 2638  2020      5           Asia  Cybertruck                  3471
# 2639  2018      8  North America     Model S                  2639
#
#       Production_Units  Avg_Price_USD  Battery_Capacity_kWh  Range_km  \
# 0                17922       92874.27                   120       704
# ...

# %%
df = df.sort_values("Region")
df
# Out:
#       Year  Month         Region       Model  Estimated_Deliveries  \
# 2112  2018     11           Asia     Model Y                 11974
# 1432  2017      1           Asia     Model S                 10239
# 242   2015     11           Asia     Model S                 15682
# 2463  2025      2           Asia     Model X                 20012
# 244   2024     11           Asia     Model 3                 12742
# ...    ...    ...            ...         ...                   ...
# 411   2025      3  North America     Model 3                  6581
# 2387  2022      2  North America  Cybertruck                 10571
# 2534  2018      5  North America  Cybertruck                  9784
# 365   2025      6  North America     Model X                  8118
# 2639  2018      8  North America     Model S                  2639
#
#       Production_Units  Avg_Price_USD  Battery_Capacity_kWh  Range_km  \
# 2112             12019       98303.28                   100       565
# ...

# %%
df.isnull().sum()
# Out:
# Year                    0
# Month                   0
# Region                  0
# Model                   0
# Estimated_Deliveries    0
# Production_Units        0
# Avg_Price_USD           0
# Battery_Capacity_kWh    0
# Range_km                0
# CO2_Saved_tons          0
# Source_Type             0
# Charging_Stations       0
# dtype: int64

# %%
Region_name = df["Region"].unique()
Region_name = Region_name.tolist()
Region_name
# Out:
# ['Asia', 'Europe', 'Middle East', 'North America']

# %%
region_dfs = {}
for region in Region_name:
    temp_df = df[df["Region"]==region].copy()
    temp_df.reset_index(drop=True, inplace=True)
    temp_df.sort_values(by=["Year","Month"], inplace=True)
    region_dfs[region] = temp_df

# %%
Asia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 Asia
#
# NameError: name 'Asia' is not defined
